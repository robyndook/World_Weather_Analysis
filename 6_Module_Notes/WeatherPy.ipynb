# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | marawi
# Processing Record 3 of Set 1 | gazojak
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | avera
# Processing Record 6 of Set 1 | pangnirtung
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | ambovombe
# Processing Record 10 of Set 1 | tashara
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | akyab
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | mogadishu
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | la ronge
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | meulaboh
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | dunedin
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | ivajlovgrad
# City not found. Skipping...
# Processing Record 29 of Set 1 | charlestown
# Processing Record 30 of Set 1 | taltal
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | matagami
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | mitu
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | pacifica
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | pacific grove
# Processing Record 44 of Set 1 | san antonio
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | allapalli
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | saint pete beach
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | truro
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | coihaique
# Processing Record 5 of Set 2 | bambanglipuro
# Processing Record 6 of Set 2 | namatanai
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | port hardy
# Processing Record 9 of Set 2 | guarda
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | boyolangu
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | lucenec
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | vao
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | tabuk
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | east london
# Processing Record 26 of Set 2 | laguna
# Processing Record 27 of Set 2 | sabang
# Processing Record 28 of Set 2 | crema
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | encruzilhada do sul
# Processing Record 32 of Set 2 | muroto
# Processing Record 33 of Set 2 | aykhal
# Processing Record 34 of Set 2 | voi
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | taos
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | agva
# City not found. Skipping...
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | ozerki
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | boralday
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | svetlaya
# Processing Record 1 of Set 3 | luruaco
# Processing Record 2 of Set 3 | hvide sande
# Processing Record 3 of Set 3 | lodja
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | shitanjing
# Processing Record 6 of Set 3 | freilassing
# Processing Record 7 of Set 3 | bluefield
# Processing Record 8 of Set 3 | san vicente de canete
# Processing Record 9 of Set 3 | kon tum
# Processing Record 10 of Set 3 | saint-joseph
# Processing Record 11 of Set 3 | kayerkan
# Processing Record 12 of Set 3 | mizan teferi
# Processing Record 13 of Set 3 | athabasca
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | sioux lookout
# Processing Record 16 of Set 3 | nanortalik
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | safaga
# Processing Record 21 of Set 3 | eyl
# Processing Record 22 of Set 3 | guarapuava
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | sibolga
# Processing Record 26 of Set 3 | akranes
# Processing Record 27 of Set 3 | pozo colorado
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | romny
# Processing Record 31 of Set 3 | colares
# Processing Record 32 of Set 3 | qasigiannguit
# Processing Record 33 of Set 3 | price
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | argentan
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | praxedis guerrero
# Processing Record 38 of Set 3 | sola
# Processing Record 39 of Set 3 | waingapu
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | zeya
# Processing Record 44 of Set 3 | diplo
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | san juan de la maguana
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | caxito
# Processing Record 49 of Set 3 | ekhabi
# Processing Record 50 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 4 | lagoa
# Processing Record 3 of Set 4 | presidencia roque saenz pena
# Processing Record 4 of Set 4 | conde
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | kalas
# Processing Record 7 of Set 4 | sorland
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | ambilobe
# Processing Record 10 of Set 4 | sao felix do xingu
# Processing Record 11 of Set 4 | bethel
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | destin
# Processing Record 15 of Set 4 | catamarca
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | sar-e pul
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 4 | port blair
# Processing Record 21 of Set 4 | balykshi
# Processing Record 22 of Set 4 | ahuimanu
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | hirara
# Processing Record 25 of Set 4 | banda aceh
# Processing Record 26 of Set 4 | ahipara
# Processing Record 27 of Set 4 | akaltara
# Processing Record 28 of Set 4 | herat
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | itarema
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | bayshore gardens
# Processing Record 33 of Set 4 | pilar
# Processing Record 34 of Set 4 | rezina
# Processing Record 35 of Set 4 | ballarat
# Processing Record 36 of Set 4 | lebu
# Processing Record 37 of Set 4 | karratha
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 40 of Set 4 | puerto cabello
# Processing Record 41 of Set 4 | reyes
# Processing Record 42 of Set 4 | alihe
# Processing Record 43 of Set 4 | amos
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | irtyshskiy
# Processing Record 48 of Set 4 | tindivanam
# Processing Record 49 of Set 4 | brae
# Processing Record 50 of Set 4 | yangjiang
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | puerto escondido
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | inhambane
# Processing Record 7 of Set 5 | salinopolis
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | oxbow
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | lovrenc na pohorju
# Processing Record 12 of Set 5 | kashi
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | victoria
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | hambantota
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | bama
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | acari
# Processing Record 22 of Set 5 | otane
# Processing Record 23 of Set 5 | hammerfest
# Processing Record 24 of Set 5 | letka
# Processing Record 25 of Set 5 | kjopsvik
# Processing Record 26 of Set 5 | isangel
# Processing Record 27 of Set 5 | general roca
# Processing Record 28 of Set 5 | ilhabela
# Processing Record 29 of Set 5 | yook
# Processing Record 30 of Set 5 | danielskuil
# Processing Record 31 of Set 5 | neiafu
# Processing Record 32 of Set 5 | lukulu
# Processing Record 33 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 5 | mpika
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | tias
# Processing Record 39 of Set 5 | yongan
# Processing Record 40 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 5 | gorinchem
# Processing Record 42 of Set 5 | lipari
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | tromso
# Processing Record 45 of Set 5 | chokurdakh
# Processing Record 46 of Set 5 | colchester
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | arlit
# Processing Record 49 of Set 5 | rio gallegos
# Processing Record 50 of Set 5 | sambava
# Processing Record 1 of Set 6 | panguna
# Processing Record 2 of Set 6 | perth
# Processing Record 3 of Set 6 | naze
# Processing Record 4 of Set 6 | myitkyina
# Processing Record 5 of Set 6 | belyy yar
# Processing Record 6 of Set 6 | obo
# Processing Record 7 of Set 6 | antioch
# Processing Record 8 of Set 6 | ocara
# Processing Record 9 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 6 | parkes
# Processing Record 11 of Set 6 | anadyr
# Processing Record 12 of Set 6 | derbent
# Processing Record 13 of Set 6 | fuyu
# Processing Record 14 of Set 6 | aalestrup
# City not found. Skipping...
# Processing Record 15 of Set 6 | sinjar
# Processing Record 16 of Set 6 | talikota
# Processing Record 17 of Set 6 | road town
# Processing Record 18 of Set 6 | bayanday
# Processing Record 19 of Set 6 | ryde
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | bundaberg
# Processing Record 22 of Set 6 | kadur
# Processing Record 23 of Set 6 | acajutla
# Processing Record 24 of Set 6 | snihurivka
# Processing Record 25 of Set 6 | berdigestyakh
# Processing Record 26 of Set 6 | lukovetskiy
# Processing Record 27 of Set 6 | miyako
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 6 | aripuana
# Processing Record 31 of Set 6 | fengzhen
# Processing Record 32 of Set 6 | smidovich
# Processing Record 33 of Set 6 | maldonado
# Processing Record 34 of Set 6 | aljezur
# Processing Record 35 of Set 6 | chernyshkovskiy
# Processing Record 36 of Set 6 | robertson
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | la asuncion
# Processing Record 39 of Set 6 | burns lake
# Processing Record 40 of Set 6 | carnarvon
# Processing Record 41 of Set 6 | cedral
# Processing Record 42 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 6 | kamiiso
# Processing Record 44 of Set 6 | palmer
# Processing Record 45 of Set 6 | mabaruma
# Processing Record 46 of Set 6 | zamania
# Processing Record 47 of Set 6 | uray
# Processing Record 48 of Set 6 | quang ngai
# Processing Record 49 of Set 6 | buin
# Processing Record 50 of Set 6 | mantua
# Processing Record 1 of Set 7 | doctor juan leon mallorquin
# Processing Record 2 of Set 7 | sorong
# Processing Record 3 of Set 7 | aloleng
# Processing Record 4 of Set 7 | belchatow
# Processing Record 5 of Set 7 | coria
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | smoky lake
# Processing Record 8 of Set 7 | aswan
# Processing Record 9 of Set 7 | kamenka
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | bitung
# Processing Record 12 of Set 7 | jalu
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | whitecourt
# Processing Record 16 of Set 7 | beira
# Processing Record 17 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 7 | khandyga
# Processing Record 19 of Set 7 | kwinana
# Processing Record 20 of Set 7 | galesong
# Processing Record 21 of Set 7 | vanimo
# Processing Record 22 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 7 | te anau
# Processing Record 24 of Set 7 | novyy urgal
# Processing Record 25 of Set 7 | nara
# Processing Record 26 of Set 7 | saint-felicien
# Processing Record 27 of Set 7 | vardo
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | san patricio
# Processing Record 30 of Set 7 | riyadh
# Processing Record 31 of Set 7 | esmeraldas
# Processing Record 32 of Set 7 | guerrero negro
# Processing Record 33 of Set 7 | bakchar
# Processing Record 34 of Set 7 | butia
# Processing Record 35 of Set 7 | gushikawa
# Processing Record 36 of Set 7 | lufilufi
# Processing Record 37 of Set 7 | margate
# Processing Record 38 of Set 7 | benguela
# Processing Record 39 of Set 7 | murowana goslina
# Processing Record 40 of Set 7 | kristiinankaupunki
# Processing Record 41 of Set 7 | clyde river
# Processing Record 42 of Set 7 | poitiers
# Processing Record 43 of Set 7 | maragogi
# Processing Record 44 of Set 7 | kutum
# Processing Record 45 of Set 7 | narrabri
# Processing Record 46 of Set 7 | huarmey
# Processing Record 47 of Set 7 | seguin
# Processing Record 48 of Set 7 | erenhot
# Processing Record 49 of Set 7 | south lake tahoe
# Processing Record 50 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | santa maria
# Processing Record 2 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 8 | roald
# Processing Record 4 of Set 8 | narsaq
# Processing Record 5 of Set 8 | port lincoln
# Processing Record 6 of Set 8 | chom bung
# City not found. Skipping...
# Processing Record 7 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 8 of Set 8 | new baltimore
# Processing Record 9 of Set 8 | sungaipenuh
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | douglas
# Processing Record 12 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 13 of Set 8 | sakakah
# Processing Record 14 of Set 8 | pangody
# Processing Record 15 of Set 8 | nileshwar
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | waddan
# Processing Record 18 of Set 8 | egvekinot
# Processing Record 19 of Set 8 | merauke
# Processing Record 20 of Set 8 | hamilton
# Processing Record 21 of Set 8 | port hedland
# Processing Record 22 of Set 8 | abu dhabi
# Processing Record 23 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 8 | normandin
# Processing Record 25 of Set 8 | krasnoselkup
# Processing Record 26 of Set 8 | tiksi
# Processing Record 27 of Set 8 | marsabit
# Processing Record 28 of Set 8 | tutoia
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | launceston
# Processing Record 31 of Set 8 | plettenberg bay
# Processing Record 32 of Set 8 | paris
# Processing Record 33 of Set 8 | sterling
# Processing Record 34 of Set 8 | poum
# Processing Record 35 of Set 8 | tommot
# Processing Record 36 of Set 8 | horsham
# Processing Record 37 of Set 8 | aklavik
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | tarko-sale
# Processing Record 40 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 41 of Set 8 | teocuitatlan de corona
# Processing Record 42 of Set 8 | souillac
# Processing Record 43 of Set 8 | thabazimbi
# Processing Record 44 of Set 8 | chizhou
# Processing Record 45 of Set 8 | palauig
# Processing Record 46 of Set 8 | arraial do cabo
# Processing Record 47 of Set 8 | gamprin
# Processing Record 48 of Set 8 | columbus
# Processing Record 49 of Set 8 | diamantino
# Processing Record 50 of Set 8 | kahului
# Processing Record 1 of Set 9 | samarai
# Processing Record 2 of Set 9 | scottsbluff
# Processing Record 3 of Set 9 | los algarrobos
# Processing Record 4 of Set 9 | chernyshevskiy
# Processing Record 5 of Set 9 | naron
# Processing Record 6 of Set 9 | raga
# Processing Record 7 of Set 9 | faya
# Processing Record 8 of Set 9 | gabu
# Processing Record 9 of Set 9 | bengkulu
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | valdivia
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | goderich
# Processing Record 14 of Set 9 | olinda
# Processing Record 15 of Set 9 | mirnyy
# Processing Record 16 of Set 9 | ishigaki
# Processing Record 17 of Set 9 | redcar
# Processing Record 18 of Set 9 | adrar
# Processing Record 19 of Set 9 | sao joao da barra
# Processing Record 20 of Set 9 | samaniego
# Processing Record 21 of Set 9 | saldanha
# Processing Record 22 of Set 9 | victor harbor
# Processing Record 23 of Set 9 | kosh-agach
# Processing Record 24 of Set 9 | moranbah
# Processing Record 25 of Set 9 | geraldton
# Processing Record 26 of Set 9 | kuopio
# Processing Record 27 of Set 9 | sacramento
# Processing Record 28 of Set 9 | nouakchott
# Processing Record 29 of Set 9 | cairns
# Processing Record 30 of Set 9 | pinawa
# Processing Record 31 of Set 9 | erzin
# Processing Record 32 of Set 9 | mount gambier
# Processing Record 33 of Set 9 | tamandare
# Processing Record 34 of Set 9 | alta floresta
# Processing Record 35 of Set 9 | cork
# Processing Record 36 of Set 9 | kapuskasing
# Processing Record 37 of Set 9 | ryotsu
# Processing Record 38 of Set 9 | portland
# Processing Record 39 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 9 | wawa
# Processing Record 41 of Set 9 | komsomolskiy
# Processing Record 42 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 | pijijiapan
# Processing Record 44 of Set 9 | quetzaltepec
# City not found. Skipping...
# Processing Record 45 of Set 9 | hasaki
# Processing Record 46 of Set 9 | ashiya
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | aksarka
# Processing Record 49 of Set 9 | la rioja
# Processing Record 50 of Set 9 | salym
# Processing Record 1 of Set 10 | coahuayana
# Processing Record 2 of Set 10 | uruzgan
# Processing Record 3 of Set 10 | jalingo
# Processing Record 4 of Set 10 | bulungu
# Processing Record 5 of Set 10 | gandajika
# Processing Record 6 of Set 10 | twin falls
# Processing Record 7 of Set 10 | port hueneme
# Processing Record 8 of Set 10 | sechura
# Processing Record 9 of Set 10 | atikokan
# Processing Record 10 of Set 10 | springville
# Processing Record 11 of Set 10 | soyo
# Processing Record 12 of Set 10 | erzincan
# Processing Record 13 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 14 of Set 10 | el prat de llobregat
# Processing Record 15 of Set 10 | mujiayingzi
# Processing Record 16 of Set 10 | yar-sale
# Processing Record 17 of Set 10 | inirida
# Processing Record 18 of Set 10 | sovetskiy
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 10 | bad wildungen
# Processing Record 22 of Set 10 | faanui
# Processing Record 23 of Set 10 | tamiahua
# Processing Record 24 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 10 | tonantins
# Processing Record 26 of Set 10 | imbituba
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | visby
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | medicine hat
# Processing Record 32 of Set 10 | omsukchan
# Processing Record 33 of Set 10 | tamworth
# Processing Record 34 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 10 | camana
# Processing Record 36 of Set 10 | yaan
# Processing Record 37 of Set 10 | taunggyi
# Processing Record 38 of Set 10 | vallenar
# Processing Record 39 of Set 10 | matay
# Processing Record 40 of Set 10 | shimoda
# Processing Record 41 of Set 10 | puerto madero
# Processing Record 42 of Set 10 | noumea
# Processing Record 43 of Set 10 | high level
# Processing Record 44 of Set 10 | girona
# Processing Record 45 of Set 10 | black river
# Processing Record 46 of Set 10 | berezovyy
# Processing Record 47 of Set 10 | san quintin
# Processing Record 48 of Set 10 | pochutla
# Processing Record 49 of Set 10 | hofn
# Processing Record 50 of Set 10 | nalut
# Processing Record 1 of Set 11 | abalak
# Processing Record 2 of Set 11 | staronizhestebliyevskaya
# Processing Record 3 of Set 11 | mananara
# Processing Record 4 of Set 11 | srednekolymsk
# Processing Record 5 of Set 11 | sarangani
# Processing Record 6 of Set 11 | miraflores
# Processing Record 7 of Set 11 | islamkot
# Processing Record 8 of Set 11 | bintulu
# Processing Record 9 of Set 11 | tumpat
# Processing Record 10 of Set 11 | tura
# Processing Record 11 of Set 11 | tautira
# Processing Record 12 of Set 11 | mamlyutka
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | srivardhan
# Processing Record 15 of Set 11 | comodoro rivadavia
# Processing Record 16 of Set 11 | mosquera
# Processing Record 17 of Set 11 | nemuro
# Processing Record 18 of Set 11 | minab
# Processing Record 19 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 20 of Set 11 | tuatapere
# Processing Record 21 of Set 11 | palmares do sul
# Processing Record 22 of Set 11 | warwick
# Processing Record 23 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 11 | batagay-alyta
# Processing Record 25 of Set 11 | cap-aux-meules
# Processing Record 26 of Set 11 | nakusp
# Processing Record 27 of Set 11 | nyrob
# Processing Record 28 of Set 11 | kerrville
# Processing Record 29 of Set 11 | katobu
# Processing Record 30 of Set 11 | bela
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | turtas
# Processing Record 33 of Set 11 | nishihara
# Processing Record 34 of Set 11 | grand gaube
# Processing Record 35 of Set 11 | xiamen
# Processing Record 36 of Set 11 | nueva londres
# Processing Record 37 of Set 11 | surgut
# Processing Record 38 of Set 11 | contamana
# Processing Record 39 of Set 11 | talaya
# Processing Record 40 of Set 11 | kattivakkam
# Processing Record 41 of Set 11 | bend
# Processing Record 42 of Set 11 | husavik
# Processing Record 43 of Set 11 | katima mulilo
# Processing Record 44 of Set 11 | dodoma
# Processing Record 45 of Set 11 | iqaluit
# Processing Record 46 of Set 11 | asilah
# Processing Record 47 of Set 11 | susurluk
# Processing Record 48 of Set 11 | hovd
# Processing Record 49 of Set 11 | abay
# Processing Record 50 of Set 11 | harlingen
# Processing Record 1 of Set 12 | mecca
# Processing Record 2 of Set 12 | ponta delgada
# Processing Record 3 of Set 12 | rongcheng
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | mount isa
# Processing Record 6 of Set 12 | garelochhead
# Processing Record 7 of Set 12 | kasongo-lunda
# Processing Record 8 of Set 12 | harper
# Processing Record 9 of Set 12 | chapais
# Processing Record 10 of Set 12 | chara
# Processing Record 11 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 12 | verkhnyaya inta
# Processing Record 13 of Set 12 | broome
# Processing Record 14 of Set 12 | atherton
# Processing Record 15 of Set 12 | vicar
# Processing Record 16 of Set 12 | muravlenko
# Processing Record 17 of Set 12 | lobito
# Processing Record 18 of Set 12 | oranjestad
# Processing Record 19 of Set 12 | peru
# Processing Record 20 of Set 12 | pasaco
# Processing Record 21 of Set 12 | cam ranh
# Processing Record 22 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 23 of Set 12 | chardara
# Processing Record 24 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | kaeo
# Processing Record 26 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 12 | saint-augustin
# Processing Record 28 of Set 12 | sayyan
# Processing Record 29 of Set 12 | kapit
# Processing Record 30 of Set 12 | mogwase
# Processing Record 31 of Set 12 | hetauda
# Processing Record 32 of Set 12 | trincomalee
# Processing Record 33 of Set 12 | bahia blanca
# Processing Record 34 of Set 12 | kronach
# Processing Record 35 of Set 12 | rio grande
# Processing Record 36 of Set 12 | energeticheskiy
# Processing Record 37 of Set 12 | conceicao do araguaia
# Processing Record 38 of Set 12 | marsh harbour
# Processing Record 39 of Set 12 | hami
# Processing Record 40 of Set 12 | quatre cocos
# Processing Record 41 of Set 12 | kailaras
# Processing Record 42 of Set 12 | matara
# Processing Record 43 of Set 12 | morro bay
# Processing Record 44 of Set 12 | mouila
# Processing Record 45 of Set 12 | maracacume
# Processing Record 46 of Set 12 | lamu
# Processing Record 47 of Set 12 | kavaratti
# Processing Record 48 of Set 12 | maniitsoq
# Processing Record 49 of Set 12 | smolensk
# Processing Record 50 of Set 12 | ambulu
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | flinders
# Processing Record 3 of Set 13 | ancud
# Processing Record 4 of Set 13 | luan
# Processing Record 5 of Set 13 | roanoke rapids
# Processing Record 6 of Set 13 | sydney
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Yellowknife  62.4560 -114.3525    -30.44        66          44
# 1        Marawi   7.9986  124.2928     72.64        79         100
# 2       Gazojak  41.1875   61.4036     44.29        49          94
# 3        Avarua -21.2078 -159.7750     78.85        83          20
# 4         Avera  33.1940  -82.5271     68.45        82         100
# 5   Pangnirtung  66.1451  -65.7125    -13.76       100         100
# 6          Hilo  19.7297 -155.0900     71.33        86         100
# 7  Saint George  37.1041 -113.5841     38.25        37           1
# 8     Ambovombe -25.1667   46.0833     81.52        64          13
# 9       Tashara  55.5195   83.5094     16.23        93          86
#
#    Wind Speed Country                 Date
# 0        3.00      CA  2022-02-04 06:10:03
# 1        3.36      PH  2022-02-04 06:14:42
# 2       16.60      TM  2022-02-04 06:14:43
# 3       14.97      CK  2022-02-04 06:14:43
# 4       15.26      US  2022-02-04 06:14:44
# 5        2.21      CA  2022-02-04 06:14:44
# 6        0.00      US  2022-02-04 06:11:17
# 7        1.99      US  2022-02-04 06:14:45
# 8       13.35      MG  2022-02-04 06:14:46
# 9       10.74      RU  2022-02-04 06:14:46

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Yellowknife      CA  2022-02-04 06:10:03  62.4560 -114.3525    -30.44
# 1       Marawi      PH  2022-02-04 06:14:42   7.9986  124.2928     72.64
# 2      Gazojak      TM  2022-02-04 06:14:43  41.1875   61.4036     44.29
# 3       Avarua      CK  2022-02-04 06:14:43 -21.2078 -159.7750     78.85
# 4        Avera      US  2022-02-04 06:14:44  33.1940  -82.5271     68.45
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          44        3.00
# 1        79         100        3.36
# 2        49          94       16.60
# 3        83          20       14.97
# 4        82         100       15.26

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
 # Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Jamestown
# Country                        US
# Date          2022-02-04 06:10:07
# Lat                        42.097
# Lng                      -79.2353
# Max Temp                    21.09
# Humidity                       67
# Cloudiness                    100
# Wind Speed                   5.01
# Name: 13, dtype: object

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Yellowknife      CA  2022-02-04 06:10:03  62.4560 -114.3525    -30.44
# 1       Marawi      PH  2022-02-04 06:14:42   7.9986  124.2928     72.64
# 2      Gazojak      TM  2022-02-04 06:14:43  41.1875   61.4036     44.29
# 4        Avera      US  2022-02-04 06:14:44  33.1940  -82.5271     68.45
# 5  Pangnirtung      CA  2022-02-04 06:14:44  66.1451  -65.7125    -13.76
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          44        3.00
# 1        79         100        3.36
# 2        49          94       16.60
# 4        82         100       15.26
# 5       100         100        2.21

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \ for Maximum Temperature', 'Max Temp',(1,-15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,55))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,25))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,25))
